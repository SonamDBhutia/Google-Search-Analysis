# %%
import pandas as pd
import matplotlib.pyplot as plt
from pytrends.request import TrendReq
Trending_topics = TrendReq(hl='en-US', tz=360)

# %%
pytrends = TrendReq(hl='en-US', tz=360)

# %%
df = pytrends.trending_searches(pn='nigeria')
df.head(10)
# Out:
#                         0
# 0          Premier League
# 1                     EPL
# 2          Brentford f.c.
# 3               MC Oluomo
# 4                   Total
# 5        Marseille vs PSG
# 6                     CBN
# 7    Sunderland vs Fulham
# 8     Kareem Abdul-Jabbar
# 9  VfL Bochum vs Dortmund

# %%
pytrends.build_payload(kw_list=["Data science"])
df = pytrends.interest_by_region()
df.sort_values(by=["Data science"], ascending=False)
# Out:
#                           Data science
# geoName
# China                              100
# Singapore                          100
# Ethiopia                            98
# India                               96
# Nigeria                             86
# ...                                ...
# Guyana                               0
# Haiti                                0
# Heard & McDonald Islands             0
# Honduras                             0
# Åland Islands                        0
#
# [250 rows x 1 columns]

# %%
Trending_topics.build_payload(kw_list=["Cloud Computing"],
							cat=0, timeframe='today 12-m')
data = Trending_topics.interest_over_time()
data = data.sort_values(by="Cloud Computing", ascending = False)
data = data.head(10)
print(data)
# Out:
#             Cloud Computing  isPartial
# date
# 2022-02-13              100      False
# 2022-12-04               97      False
# 2022-11-27               97      False
# 2022-02-27               94      False
# 2022-03-06               94      False
# 2022-03-20               92      False
# 2022-06-05               91      False
# 2022-05-15               91      False
# 2022-08-21               90      False
# 2022-11-13               90      False

# %%
kw_list=["Cloud Computing"]
Trending_topics.build_payload(kw_list,cat=0, timeframe='today 12-m')

# %%
data = Trending_topics.interest_by_region()
data = data.sort_values(by="Cloud Computing",
						ascending = False)
data = data.head(10)
print(data)
# Out:
#            Cloud Computing
# geoName
# Ethiopia               100
# Zimbabwe                91
# Nepal                   57
# India                   57
# Cameroon                54
# Kenya                   46
# Sri Lanka               42
# Uganda                  39
# Pakistan                36
# Ghana                   35

# %%
data.reset_index().plot(x='geoName', y='Cloud Computing',
						figsize=(10,5), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
df = Trending_topics.top_charts(2020, hl='en-US',
								tz=300, geo='GLOBAL')
df.head(10)
# Out:
#                   title exploreQuery
# 0           Coronavirus
# 1      Election results
# 2           Kobe Bryant
# 3                  Zoom
# 4                   IPL
# 5  India vs New Zealand
# 6    Coronavirus update
# 7  Coronavirus symptoms
# 8             Joe Biden
# 9      Google Classroom

# %%
Trending_topics.build_payload(kw_list=['Cloud Computing'])
related_queries = Trending_topics.related_queries()
related_queries.values()
# Out:
# dict_values([{'top':                           query  value
# 0                          what    100
# 1                 what is cloud     94
# 2                           the     87
# 3       what is cloud computing     83
# 4                         which     41
# 5       cloud computing service     37
# 6   what is the cloud computing     35
# 7      cloud computing services     35
# 8                cloud services     35
# 9                cloud security     34
# 10     cloud computing security     33
# 11       google cloud computing     25
# 12                 google cloud     25
# 13     cloud computing software     25
# 14                          aws     23
# 15      cloud computing meaning     23
# 16          aws cloud computing     23
# 17                    aws cloud     22
# 18       cloud computing system     20
# 19   cloud computing definition     20
# 20  security in cloud computing     19
# 21   cloud computing technology     19
# 22      cloud computing example     18
# 23                cloud storage     17
# 24        cloud computing types     17, 'rising':                                                 query  value
# 0                        global x cloud computing etf  13750
# 1                      wisdomtree cloud computing etf  13200
# 2   what would be an ideal scenario for using edge...  10050
# 3   what describes the relationship between edge c...   8900
# 4   a software developer wants to add a new featur...   6550
# 5   what would be an ideal scenario for using edge...   5850
# 6   a chain of dry-cleaning outlets wants to impro...   5800
# 7   an electronics company wants to use a type of ...   5500
# 8   what distinguishes accenture’s cloud capabilit...   5450
# 9            infrastructure apis help in provisioning   5000
# 10  how can edge computing be used to improve sust...   4600
# 11  accenture has signed a multi-year agreement to...   4600
# 12                                           quillbot   4350
# 13  what is a recent trend relating to sustainabil...   3750
# 14  how does the accenture mynav green cloud advis...   3450
# 15  what does accenture mean by sustainability wil...   3300
# 16                             what is edge computing   2700
# 17  what is the first step in the process of deplo...   2250
# 18                              blockchain technology   2200
# 19  what is an example of new technology having a ...   1450
# 20                                cloud computing mcq   1250
# 21                                         blockchain   1000
# 22                         cloud computing javatpoint    900
# 23                                cloud computing etf    900
# 24                                         kubernetes    850}])

# %%
keywords = Trending_topics.suggestions(
keyword='Cloud Computing')
df = pd.DataFrame(keywords)
df.drop(columns= 'mid')
# Out:
#                                      title                       type
# 0                          Cloud computing                      Topic
# 1                            Alibaba Cloud  Computer software company
# 2                 Cloud computing security                      Topic
# 3                      IBM cloud computing          Computer software
# 4  TransferXL - NIMBUS CLOUD COMPUTING B.V                      Topic

# %%
pytrends = TrendReq(hl='en-US', tz=360)
pytrends.build_payload(kw_list=['Programming'])
pytrends = pytrends.interest_over_time()
fig, ax = plt.subplots(figsize=(10, 5))
pytrends['Programming'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for Analysis', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()
